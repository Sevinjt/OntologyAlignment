# %% [markdown]
# # Owl2vec_star_ext
# In this process, we get ontology files and to change it to embedding model

# %%
import owl2vec4mappings

# Parameters:
# ontology_file1
# ontology_file2
# mapping_file
# config_file
# uri_doc
# lit_doc
# mix_doc
# but there are some parameters you can change in config file
gensim_model = owl2vec4mappings.extract_owl2vec_model(ontology_file1 = "./case_studies/Data/snomed.pharm.owl",
                                                ontology_file2 = './case_studies/Data/ncit.pharm.owl',
                                                mapping_file = './case_studies/Data/trainUnionS2Nph.tsv',
                                                config_file = "./default1.cfg",
                                                uri_doc = True, lit_doc = True, mix_doc = True)
# Out:
# * Owlready2 * Warning: optimized Cython parser module 'owlready2_optimized' is not available, defaulting to slower Python implementation
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sev_s\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# INFO: 1
# INFO:
#  Access the ontology ...
# INFO: There are 527246 triples in the ontology
# * Owlready2 * Creating new ontology ncit.neoplas <./case_studies/Data/ncit.neoplas.owl#>.
# * Owlready2 * ADD TRIPLE ./case_studies/Data/ncit.neoplas.owl http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#Ontology
# * Owlready2 *     ...loading ontology ncit.neoplas from ./case_studies/Data/ncit.neoplas.owl...
# * OwlReady2 * Importing 573546 object triples from ontology ./case_studies/Data/ncit.neoplas.owl# ...
# * OwlReady2 * Importing 570700 data triples from ontology ./case_studies/Data/ncit.neoplas.owl# ...
# * Owlready2 * Reseting property ann.use_in_alignment: new triples are now available.
# * Owlready2 *     ...226 properties found: R100, R101, R102, R103, R104, R105, R106, R107, R108, R110, R111, R112, R113, R114, R115, R116, R122, R123, R124, R125, R126, R130, R131, R132, R133, R135, R136, R137, R138, R139, R140, R141, R142, R145, R146, R150, R153, R155, R40, R156, R158, R37, R159, R160, R163, R165, R166, R167, R168, R169, R170, R171, R172, R173, R174, R175, R176, R177, R178, R179, R180, R181, R182, R23, R24, R25, R26, R27, R28, R29, R30, R31, R32, R34, R35, R36, R38, R39, R41, R42, R44, R45, R46, R47, R48, R49, R50, R51, R52, R53, R54, R66, R72, R81, R82, R88, R89, comment, label, versionInfo, use_in_alignment, A1, A10, A11, A12, A13, A14, A15, A16, A17, A18, A19, A2, A20, A21, A22, A23, A24, A25, A26, A27, A28, A29, A3, A30, A33, A34, A4, A5, A6, A7, A8, A9, NHC0, P100, P101, P102, P106, P107, P108, P167, P171, P175, P200, P201, P203, P204, P205, P207, P208, P210, P211, P215, P216, P302, P310, P315, P316, P317, P319, P320, P321, P322, P325, P329, P330, P331, P332, P333, P334, P350, P351, P352, P353, P355, P356, P357, P358, P359, P360, P361, P362, P363, P364, P365, P366, P367, P368, P369, P371, P372, P375, P376, P377, P378, P379, P380, P381, P382, P383, P384, P385, P386, P387, P388, P389, P390, P391, P392, P393, P394, P395, P396, P397, P398, P90, P92, P93, P96, P97, P98, default, required, defaultLanguage, readOnly, date
# INFO: There are 1671492 triples in the ontology
# INFO: Creating ontology graph projection...
# INFO: 	Extracting subsumption triples
# INFO: 		Time extracting subsumption: 5.194763660430908 seconds
# INFO: 	Extracting equivalence triples
# INFO: 		Time extracting equivalences: 5.894704103469849 seconds
# INFO: 	Extracting class membership triples.
# INFO: 		Time extracting class membership: 133.02309107780457 seconds
# INFO: 	Extracting sameAs triples
# INFO: 		Time extracting sameAs: 0.06135892868041992 seconds
# INFO: 	Extracting triples associated to 1003703000
# INFO: 		Time extracting triples for property: 0.1804180145263672 seconds
# INFO: 	Extracting triples associated to 762705008
# INFO: 		Time extracting triples for property: 0.15406537055969238 seconds
# INFO: 	Extracting triples associated to 1003735000
# INFO: 		Time extracting triples for property: 0.16599202156066895 seconds
# INFO: 	Extracting triples associated to 1148965004
# INFO: 		Time extracting triples for property: 0.189805269241333 seconds
# INFO: 	Extracting triples associated to 1148967007
# INFO: 		Time extracting triples for property: 0.15340304374694824 seconds
# INFO: 	Extracting triples associated to 1148968002
# INFO: 		Time extracting triples for property: 0.2504146099090576 seconds
# INFO: 	Extracting triples associated to 1148969005
# INFO: 		Time extracting triples for property: 0.19102859497070312 seconds
# INFO: 	Extracting triples associated to 1149366004
# INFO: 		Time extracting triples for property: 0.1831662654876709 seconds
# INFO: 	Extracting triples associated to 1149367008
# INFO: 		Time extracting triples for property: 0.2384185791015625 seconds
# INFO: 	Extracting triples associated to 116676008
# INFO: 		Time extracting triples for property: 1.865508794784546 seconds
# INFO: 	Extracting triples associated to 116686009
# INFO: 		Time extracting triples for property: 0.20409369468688965 seconds
# INFO: 	Extracting triples associated to 118168003
# INFO: 		Time extracting triples for property: 0.18420863151550293 seconds
# INFO: 	Extracting triples associated to 118169006
# INFO: 		Time extracting triples for property: 0.23386359214782715 seconds
# INFO: 	Extracting triples associated to 118170007
# INFO: 		Time extracting triples for property: 0.1756153106689453 seconds
# INFO: 	Extracting triples associated to 118171006
# INFO: 		Time extracting triples for property: 0.26000213623046875 seconds
# INFO: 	Extracting triples associated to 127489000
# INFO: 		Time extracting triples for property: 0.20654821395874023 seconds
# INFO: 	Extracting triples associated to 762951001
# INFO: 		Time extracting triples for property: 0.18067049980163574 seconds
# INFO: 	Extracting triples associated to 738774007
# INFO: 		Time extracting triples for property: 0.17642784118652344 seconds
# INFO: 	Extracting triples associated to 131195008
# INFO: 		Time extracting triples for property: 0.17137432098388672 seconds
# INFO: 	Extracting triples associated to 246075003
# INFO: 		Time extracting triples for property: 0.20370078086853027 seconds
# INFO: 	Extracting triples associated to 47429007
# INFO: 		Time extracting triples for property: 0.18487000465393066 seconds
# INFO: 	Extracting triples associated to 246090004
# INFO: 		Time extracting triples for property: 0.17825031280517578 seconds
# INFO: 	Extracting triples associated to 246093002
# INFO: 		Time extracting triples for property: 0.19106554985046387 seconds
# INFO: 	Extracting triples associated to 246112005
# INFO: 		Time extracting triples for property: 0.17115044593811035 seconds
# INFO: 	Extracting triples associated to 246454002
# INFO: 		Time extracting triples for property: 0.3099186420440674 seconds
# INFO: 	Extracting triples associated to 246456000
# INFO: 		Time extracting triples for property: 0.15031218528747559 seconds
# INFO: 	Extracting triples associated to 246501002
# INFO: 		Time extracting triples for property: 0.20945286750793457 seconds
# INFO: 	Extracting triples associated to 246513007
# INFO: 		Time extracting triples for property: 0.18249773979187012 seconds
# INFO: 	Extracting triples associated to 246514001
# INFO: 		Time extracting triples for property: 0.19789576530456543 seconds
# INFO: 	Extracting triples associated to 255234002
# INFO: 		Time extracting triples for property: 0.20233392715454102 seconds
# INFO: 	Extracting triples associated to 726633004
# INFO: 		Time extracting triples for property: 0.18425416946411133 seconds
# INFO: 	Extracting triples associated to 260507000
# INFO: 		Time extracting triples for property: 0.20820140838623047 seconds
# INFO: 	Extracting triples associated to 260686004
# INFO: 		Time extracting triples for property: 0.32422399520874023 seconds
# INFO: 	Extracting triples associated to 260870009
# INFO: 		Time extracting triples for property: 0.16405963897705078 seconds
# INFO: 	Extracting triples associated to 263502005
# INFO: 		Time extracting triples for property: 0.19962787628173828 seconds
# INFO: 	Extracting triples associated to 272741003
# INFO: 		Time extracting triples for property: 0.25960731506347656 seconds
# INFO: 	Extracting triples associated to 288556008
# INFO: 		Time extracting triples for property: 0.17992734909057617 seconds
# INFO: 	Extracting triples associated to 320091000221107
# INFO: 		Time extracting triples for property: 0.20107007026672363 seconds
# INFO: 	Extracting triples associated to 363589002
# INFO: 		Time extracting triples for property: 0.15965032577514648 seconds
# INFO: 	Extracting triples associated to 363698007
# INFO: 		Time extracting triples for property: 1.7961502075195312 seconds
# INFO: 	Extracting triples associated to 363699004
# INFO: 		Time extracting triples for property: 0.1801137924194336 seconds
# INFO: 	Extracting triples associated to 405815000
# INFO: 		Time extracting triples for property: 0.2993927001953125 seconds
# INFO: 	Extracting triples associated to 363700003
# INFO: 		Time extracting triples for property: 0.16824960708618164 seconds
# INFO: 	Extracting triples associated to 405816004
# INFO: 		Time extracting triples for property: 0.18872547149658203 seconds
# INFO: 	Extracting triples associated to 363701004
# INFO: 		Time extracting triples for property: 0.18192648887634277 seconds
# INFO: 	Extracting triples associated to 363702006
# INFO: 		Time extracting triples for property: 0.1611158847808838 seconds
# INFO: 	Extracting triples associated to 363703001
# INFO: 		Time extracting triples for property: 0.1743025779724121 seconds
# INFO: 	Extracting triples associated to 363704007
# INFO: 		Time extracting triples for property: 0.2277846336364746 seconds
# INFO: 	Extracting triples associated to 363705008
# INFO: 		Time extracting triples for property: 0.16803264617919922 seconds
# INFO: 	Extracting triples associated to 363709002
# INFO: 		Time extracting triples for property: 0.16884684562683105 seconds
# INFO: 	Extracting triples associated to 363710007
# INFO: 		Time extracting triples for property: 0.16529464721679688 seconds
# INFO: 	Extracting triples associated to 363713009
# INFO: 		Time extracting triples for property: 0.21976780891418457 seconds
# INFO: 	Extracting triples associated to 363714003
# INFO: 		Time extracting triples for property: 0.2230970859527588 seconds
# INFO: 	Extracting triples associated to 370129005
# INFO: 		Time extracting triples for property: 0.16415047645568848 seconds
# INFO: 	Extracting triples associated to 370130000
# INFO: 		Time extracting triples for property: 0.1864464282989502 seconds
# INFO: 	Extracting triples associated to 370131001
# INFO: 		Time extracting triples for property: 0.1699361801147461 seconds
# INFO: 	Extracting triples associated to 370132008
# INFO: 		Time extracting triples for property: 0.180375337600708 seconds
# INFO: 	Extracting triples associated to 370133003
# INFO: 		Time extracting triples for property: 0.18024063110351562 seconds
# INFO: 	Extracting triples associated to 370134009
# INFO: 		Time extracting triples for property: 0.18077874183654785 seconds
# INFO: 	Extracting triples associated to 370135005
# INFO: 		Time extracting triples for property: 0.30738377571105957 seconds
# INFO: 	Extracting triples associated to 371881003
# INFO: 		Time extracting triples for property: 0.17775416374206543 seconds
# INFO: 	Extracting triples associated to 405813007
# INFO: 		Time extracting triples for property: 0.24755501747131348 seconds
# INFO: 	Extracting triples associated to 405814001
# INFO: 		Time extracting triples for property: 0.18230104446411133 seconds
# INFO: 	Extracting triples associated to 408729009
# INFO: 		Time extracting triples for property: 0.22746825218200684 seconds
# INFO: 	Extracting triples associated to 408730004
# INFO: 		Time extracting triples for property: 0.193831205368042 seconds
# INFO: 	Extracting triples associated to 408731000
# INFO: 		Time extracting triples for property: 0.19000244140625 seconds
# INFO: 	Extracting triples associated to 408732007
# INFO: 		Time extracting triples for property: 0.18424630165100098 seconds
# INFO: 	Extracting triples associated to 410675002
# INFO: 		Time extracting triples for property: 0.3258483409881592 seconds
# INFO: 	Extracting triples associated to 411116001
# INFO: 		Time extracting triples for property: 0.1750049591064453 seconds
# INFO: 	Extracting triples associated to 418775008
# INFO: 		Time extracting triples for property: 0.17324399948120117 seconds
# INFO: 	Extracting triples associated to 419066007
# INFO: 		Time extracting triples for property: 0.2045269012451172 seconds
# INFO: 	Extracting triples associated to 424226004
# INFO: 		Time extracting triples for property: 0.2001180648803711 seconds
# INFO: 	Extracting triples associated to 424244007
# INFO: 		Time extracting triples for property: 0.1848752498626709 seconds
# INFO: 	Extracting triples associated to 424361007
# INFO: 		Time extracting triples for property: 0.17280173301696777 seconds
# INFO: 	Extracting triples associated to 424876005
# INFO: 		Time extracting triples for property: 0.19287657737731934 seconds
# INFO: 	Extracting triples associated to 425391005
# INFO: 		Time extracting triples for property: 0.22282075881958008 seconds
# INFO: 	Extracting triples associated to 42752001
# INFO: 		Time extracting triples for property: 0.23235201835632324 seconds
# INFO: 	Extracting triples associated to 609096000
# INFO: 		Time extracting triples for property: 2.2399911880493164 seconds
# INFO: 	Extracting triples associated to 704319004
# INFO: 		Time extracting triples for property: 0.17986273765563965 seconds
# INFO: 	Extracting triples associated to 704320005
# INFO: 		Time extracting triples for property: 0.17171764373779297 seconds
# INFO: 	Extracting triples associated to 704321009
# INFO: 		Time extracting triples for property: 0.15618491172790527 seconds
# INFO: 	Extracting triples associated to 704322002
# INFO: 		Time extracting triples for property: 0.22093486785888672 seconds
# INFO: 	Extracting triples associated to 704323007
# INFO: 		Time extracting triples for property: 0.17962312698364258 seconds
# INFO: 	Extracting triples associated to 704324001
# INFO: 		Time extracting triples for property: 0.16741371154785156 seconds
# INFO: 	Extracting triples associated to 704325000
# INFO: 		Time extracting triples for property: 0.1571211814880371 seconds
# INFO: 	Extracting triples associated to 704326004
# INFO: 		Time extracting triples for property: 0.2151622772216797 seconds
# INFO: 	Extracting triples associated to 704327008
# INFO: 		Time extracting triples for property: 0.20019745826721191 seconds
# INFO: 	Extracting triples associated to 704346009
# INFO: 		Time extracting triples for property: 0.16275763511657715 seconds
# INFO: 	Extracting triples associated to 704347000
# INFO: 		Time extracting triples for property: 0.18102359771728516 seconds
# INFO: 	Extracting triples associated to 704647008
# INFO: 		Time extracting triples for property: 0.15433669090270996 seconds
# INFO: 	Extracting triples associated to 718497002
# INFO: 		Time extracting triples for property: 0.19746971130371094 seconds
# INFO: 	Extracting triples associated to 719715003
# INFO: 		Time extracting triples for property: 0.20589542388916016 seconds
# INFO: 	Extracting triples associated to 719722006
# INFO: 		Time extracting triples for property: 0.15839362144470215 seconds
# INFO: 	Extracting triples associated to 726542003
# INFO: 		Time extracting triples for property: 0.20595121383666992 seconds
# INFO: 	Extracting triples associated to 732943007
# INFO: 		Time extracting triples for property: 0.25605130195617676 seconds
# INFO: 	Extracting triples associated to 732945000
# INFO: 		Time extracting triples for property: 0.1674518585205078 seconds
# INFO: 	Extracting triples associated to 732947008
# INFO: 		Time extracting triples for property: 0.1715223789215088 seconds
# INFO: 	Extracting triples associated to 733722007
# INFO: 		Time extracting triples for property: 0.16849970817565918 seconds
# INFO: 	Extracting triples associated to 733725009
# INFO: 		Time extracting triples for property: 0.18833541870117188 seconds
# INFO: 	Extracting triples associated to 733928003
# INFO: 		Time extracting triples for property: 0.17154145240783691 seconds
# INFO: 	Extracting triples associated to 733930001
# INFO: 		Time extracting triples for property: 0.17577409744262695 seconds
# INFO: 	Extracting triples associated to 774081006
# INFO: 		Time extracting triples for property: 0.17130160331726074 seconds
# INFO: 	Extracting triples associated to 733931002
# INFO: 		Time extracting triples for property: 0.17779183387756348 seconds
# INFO: 	Extracting triples associated to 733932009
# INFO: 		Time extracting triples for property: 0.1892232894897461 seconds
# INFO: 	Extracting triples associated to 733933004
# INFO: 		Time extracting triples for property: 0.17270469665527344 seconds
# INFO: 	Extracting triples associated to 734136001
# INFO: 		Time extracting triples for property: 0.1754453182220459 seconds
# INFO: 	Extracting triples associated to 734137005
# INFO: 		Time extracting triples for property: 0.18361401557922363 seconds
# INFO: 	Extracting triples associated to 736472000
# INFO: 		Time extracting triples for property: 0.18125653266906738 seconds
# INFO: 	Extracting triples associated to 736473005
# INFO: 		Time extracting triples for property: 0.16401386260986328 seconds
# INFO: 	Extracting triples associated to 736474004
# INFO: 		Time extracting triples for property: 0.15975022315979004 seconds
# INFO: 	Extracting triples associated to 736475003
# INFO: 		Time extracting triples for property: 0.1955869197845459 seconds
# INFO: 	Extracting triples associated to 736476002
# INFO: 		Time extracting triples for property: 0.17965245246887207 seconds
# INFO: 	Extracting triples associated to 736518005
# INFO: 		Time extracting triples for property: 0.17377233505249023 seconds
# INFO: 	Extracting triples associated to 762949000
# INFO: 		Time extracting triples for property: 0.14896345138549805 seconds
# INFO: 	Extracting triples associated to 763032000
# INFO: 		Time extracting triples for property: 0.19564223289489746 seconds
# INFO: 	Extracting triples associated to 766939001
# INFO: 		Time extracting triples for property: 0.18617725372314453 seconds
# INFO: 	Extracting triples associated to 774158006
# INFO: 		Time extracting triples for property: 0.16698288917541504 seconds
# INFO: 	Extracting triples associated to 774159003
# INFO: 		Time extracting triples for property: 0.18790340423583984 seconds
# INFO: 	Extracting triples associated to 774160008
# INFO: 		Time extracting triples for property: 0.15541529655456543 seconds
# INFO: 	Extracting triples associated to 774163005
# INFO: 		Time extracting triples for property: 0.17881512641906738 seconds
# INFO: 	Extracting triples associated to 827081001
# INFO: 		Time extracting triples for property: 0.18065690994262695 seconds
# INFO: 	Extracting triples associated to 836358009
# INFO: 		Time extracting triples for property: 0.1621568202972412 seconds
# INFO: 	Extracting triples associated to 840560000
# INFO: 		Time extracting triples for property: 0.17102813720703125 seconds
# INFO: 	Extracting triples associated to 860779006
# INFO: 		Time extracting triples for property: 0.2722756862640381 seconds
# INFO: 	Extracting triples associated to 860781008
# INFO: 		Time extracting triples for property: 0.16479921340942383 seconds
# INFO: 	Extracting data property assertions
# INFO: 		Time extracting data property assertions: 1.104341983795166 seconds
# INFO: 	Extracting complex equivalence axioms
# INFO: 		Time extracting complex equivalence axioms: 3175.936675786972 seconds
# INFO: 	Extracting annotations.
# INFO: 		Time extracting annotations: 68.22828078269958 seconds
# INFO: Projection created into a Graph object (RDFlib library)
# INFO: Creating ontology graph projection...
# INFO: 	Extracting subsumption triples
# INFO: 		Time extracting subsumption: 6.240050554275513 seconds
# INFO: 	Extracting equivalence triples
# INFO: 		Time extracting equivalences: 5.710983514785767 seconds
# INFO: 	Extracting class membership triples.
# INFO: 		Time extracting class membership: 126.56526827812195 seconds
# INFO: 	Extracting sameAs triples
# INFO: 		Time extracting sameAs: 0.08580446243286133 seconds
# INFO: 	Extracting triples associated to R100
# INFO: 		Time extracting triples for property: 0.20129084587097168 seconds
# INFO: 	Extracting triples associated to R101
# INFO: 		Time extracting triples for property: 0.3776557445526123 seconds
# INFO: 	Extracting triples associated to R102
# INFO: 		Time extracting triples for property: 0.18893694877624512 seconds
# INFO: 	Extracting triples associated to R103
# INFO: 		Time extracting triples for property: 0.2488727569580078 seconds
# INFO: 	Extracting triples associated to R104
# INFO: 		Time extracting triples for property: 0.23052620887756348 seconds
# INFO: 	Extracting triples associated to R105
# INFO: 		Time extracting triples for property: 0.28485941886901855 seconds
# INFO: 	Extracting triples associated to R106
# INFO: 		Time extracting triples for property: 0.17941808700561523 seconds
# INFO: 	Extracting triples associated to R107
# INFO: 		Time extracting triples for property: 0.1796584129333496 seconds
# INFO: 	Extracting triples associated to R108
# INFO: 		Time extracting triples for property: 0.5380570888519287 seconds
# INFO: 	Extracting triples associated to R110
# INFO: 		Time extracting triples for property: 0.19389772415161133 seconds
# INFO: 	Extracting triples associated to R111
# INFO: 		Time extracting triples for property: 0.1543114185333252 seconds
# INFO: 	Extracting triples associated to R112
# INFO: 		Time extracting triples for property: 0.18373775482177734 seconds
# INFO: 	Extracting triples associated to R113
# INFO: 		Time extracting triples for property: 0.20622754096984863 seconds
# INFO: 	Extracting triples associated to R114
# INFO: 		Time extracting triples for property: 0.37105393409729004 seconds
# INFO: 	Extracting triples associated to R115
# INFO: 		Time extracting triples for property: 0.5371427536010742 seconds
# INFO: 	Extracting triples associated to R116
# INFO: 		Time extracting triples for property: 0.23090744018554688 seconds
# INFO: 	Extracting triples associated to R122
# INFO: 		Time extracting triples for property: 0.1847994327545166 seconds
# INFO: 	Extracting triples associated to R123
# INFO: 		Time extracting triples for property: 0.20805859565734863 seconds
# INFO: 	Extracting triples associated to R124
# INFO: 		Time extracting triples for property: 0.16887855529785156 seconds
# INFO: 	Extracting triples associated to R125
# INFO: 		Time extracting triples for property: 0.17418169975280762 seconds
# INFO: 	Extracting triples associated to R126
# INFO: 		Time extracting triples for property: 0.20046663284301758 seconds
# INFO: 	Extracting triples associated to R130
# INFO: 		Time extracting triples for property: 0.17010116577148438 seconds
# INFO: 	Extracting triples associated to R131
# INFO: 		Time extracting triples for property: 0.22491168975830078 seconds
# INFO: 	Extracting triples associated to R132
# INFO: 		Time extracting triples for property: 0.23096871376037598 seconds
# INFO: 	Extracting triples associated to R133
# INFO: 		Time extracting triples for property: 0.16723251342773438 seconds
# INFO: 	Extracting triples associated to R135
# INFO: 		Time extracting triples for property: 0.1816549301147461 seconds
# INFO: 	Extracting triples associated to R136
# INFO: 		Time extracting triples for property: 0.17118525505065918 seconds
# INFO: 	Extracting triples associated to R137
# INFO: 		Time extracting triples for property: 0.1908588409423828 seconds
# INFO: 	Extracting triples associated to R138
# INFO: 		Time extracting triples for property: 0.19255328178405762 seconds
# INFO: 	Extracting triples associated to R139
# INFO: 		Time extracting triples for property: 0.18064355850219727 seconds
# INFO: 	Extracting triples associated to R140
# INFO: 		Time extracting triples for property: 0.18801593780517578 seconds
# INFO: 	Extracting triples associated to R141
# INFO: 		Time extracting triples for property: 0.16322588920593262 seconds
# INFO: 	Extracting triples associated to R142
# INFO: 		Time extracting triples for property: 0.2801527976989746 seconds
# INFO: 	Extracting triples associated to R145
# INFO: 		Time extracting triples for property: 0.1952505111694336 seconds
# INFO: 	Extracting triples associated to R146
# INFO: 		Time extracting triples for property: 0.18869805335998535 seconds
# INFO: 	Extracting triples associated to R150
# INFO: 		Time extracting triples for property: 0.17202329635620117 seconds
# INFO: 	Extracting triples associated to R153
# INFO: 		Time extracting triples for property: 0.1780397891998291 seconds
# INFO: 	Extracting triples associated to R155
# INFO: 		Time extracting triples for property: 0.17219996452331543 seconds
# INFO: 	Extracting triples associated to R40
# INFO: 		Time extracting triples for property: 0.21501922607421875 seconds
# INFO: 	Extracting triples associated to R156
# INFO: 		Time extracting triples for property: 0.23895668983459473 seconds
# INFO: 	Extracting triples associated to R158
# INFO: 		Time extracting triples for property: 0.18726134300231934 seconds
# INFO: 	Extracting triples associated to R37
# INFO: 		Time extracting triples for property: 0.5008678436279297 seconds
# INFO: 	Extracting triples associated to R159
# INFO: 		Time extracting triples for property: 0.15545344352722168 seconds
# INFO: 	Extracting triples associated to R160
# INFO: 		Time extracting triples for property: 0.15955829620361328 seconds
# INFO: 	Extracting triples associated to R163
# INFO: 		Time extracting triples for property: 0.17481780052185059 seconds
# INFO: 	Extracting triples associated to R165
# INFO: 		Time extracting triples for property: 0.19813084602355957 seconds
# INFO: 	Extracting triples associated to R166
# INFO: 		Time extracting triples for property: 0.18564414978027344 seconds
# INFO: 	Extracting triples associated to R167
# INFO: 		Time extracting triples for property: 0.15656566619873047 seconds
# INFO: 	Extracting triples associated to R168
# INFO: 		Time extracting triples for property: 0.18389487266540527 seconds
# INFO: 	Extracting triples associated to R169
# INFO: 		Time extracting triples for property: 0.15465664863586426 seconds
# INFO: 	Extracting triples associated to R170
# INFO: 		Time extracting triples for property: 0.18948841094970703 seconds
# INFO: 	Extracting triples associated to R171
# INFO: 		Time extracting triples for property: 0.16147661209106445 seconds
# INFO: 	Extracting triples associated to R172
# INFO: 		Time extracting triples for property: 0.19633769989013672 seconds
# INFO: 	Extracting triples associated to R173
# INFO: 		Time extracting triples for property: 0.26343321800231934 seconds
# INFO: 	Extracting triples associated to R174
# INFO: 		Time extracting triples for property: 0.2029247283935547 seconds
# INFO: 	Extracting triples associated to R175
# INFO: 		Time extracting triples for property: 0.4516294002532959 seconds
# INFO: 	Extracting triples associated to R176
# INFO: 		Time extracting triples for property: 0.2149817943572998 seconds
# INFO: 	Extracting triples associated to R177
# INFO: 		Time extracting triples for property: 0.438922643661499 seconds
# INFO: 	Extracting triples associated to R178
# INFO: 		Time extracting triples for property: 0.19315505027770996 seconds
# INFO: 	Extracting triples associated to R179
# INFO: 		Time extracting triples for property: 0.19903039932250977 seconds
# INFO: 	Extracting triples associated to R180
# INFO: 		Time extracting triples for property: 0.153731107711792 seconds
# INFO: 	Extracting triples associated to R181
# INFO: 		Time extracting triples for property: 0.18239307403564453 seconds
# INFO: 	Extracting triples associated to R182
# INFO: 		Time extracting triples for property: 0.18905854225158691 seconds
# INFO: 	Extracting triples associated to R23
# INFO: 		Time extracting triples for property: 0.15663504600524902 seconds
# INFO: 	Extracting triples associated to R24
# INFO: 		Time extracting triples for property: 0.2554478645324707 seconds
# INFO: 	Extracting triples associated to R25
# INFO: 		Time extracting triples for property: 0.3239412307739258 seconds
# INFO: 	Extracting triples associated to R26
# INFO: 		Time extracting triples for property: 0.19435667991638184 seconds
# INFO: 	Extracting triples associated to R27
# INFO: 		Time extracting triples for property: 0.1551213264465332 seconds
# INFO: 	Extracting triples associated to R28
# INFO: 		Time extracting triples for property: 0.20576047897338867 seconds
# INFO: 	Extracting triples associated to R29
# INFO: 		Time extracting triples for property: 0.1565546989440918 seconds
# INFO: 	Extracting triples associated to R30
# INFO: 		Time extracting triples for property: 0.2064647674560547 seconds
# INFO: 	Extracting triples associated to R31
# INFO: 		Time extracting triples for property: 0.20826172828674316 seconds
# INFO: 	Extracting triples associated to R32
# INFO: 		Time extracting triples for property: 0.1765000820159912 seconds
# INFO: 	Extracting triples associated to R34
# INFO: 		Time extracting triples for property: 0.18995952606201172 seconds
# INFO: 	Extracting triples associated to R35
# INFO: 		Time extracting triples for property: 0.23655033111572266 seconds
# INFO: 	Extracting triples associated to R36
# INFO: 		Time extracting triples for property: 0.17108631134033203 seconds
# INFO: 	Extracting triples associated to R38
# INFO: 		Time extracting triples for property: 0.20496892929077148 seconds
# INFO: 	Extracting triples associated to R39
# INFO: 		Time extracting triples for property: 0.16825580596923828 seconds
# INFO: 	Extracting triples associated to R41
# INFO: 		Time extracting triples for property: 0.1591792106628418 seconds
# INFO: 	Extracting triples associated to R42
# INFO: 		Time extracting triples for property: 0.17139339447021484 seconds
# INFO: 	Extracting triples associated to R44
# INFO: 		Time extracting triples for property: 0.17616963386535645 seconds
# INFO: 	Extracting triples associated to R45
# INFO: 		Time extracting triples for property: 0.18065428733825684 seconds
# INFO: 	Extracting triples associated to R46
# INFO: 		Time extracting triples for property: 0.17345905303955078 seconds
# INFO: 	Extracting triples associated to R47
# INFO: 		Time extracting triples for property: 0.15783238410949707 seconds
# INFO: 	Extracting triples associated to R48
# INFO: 		Time extracting triples for property: 0.2131972312927246 seconds
# INFO: 	Extracting triples associated to R49
# INFO: 		Time extracting triples for property: 0.2083125114440918 seconds
# INFO: 	Extracting triples associated to R50
# INFO: 		Time extracting triples for property: 0.1775057315826416 seconds
# INFO: 	Extracting triples associated to R51
# INFO: 		Time extracting triples for property: 0.21877264976501465 seconds
# INFO: 	Extracting triples associated to R52
# INFO: 		Time extracting triples for property: 0.20828485488891602 seconds
# INFO: 	Extracting triples associated to R53
# INFO: 		Time extracting triples for property: 0.2055213451385498 seconds
# INFO: 	Extracting triples associated to R54
# INFO: 		Time extracting triples for property: 0.19604086875915527 seconds
# INFO: 	Extracting triples associated to R66
# INFO: 		Time extracting triples for property: 0.16944503784179688 seconds
# INFO: 	Extracting triples associated to R72
# INFO: 		Time extracting triples for property: 0.18858885765075684 seconds
# INFO: 	Extracting triples associated to R81
# INFO: 		Time extracting triples for property: 0.186448335647583 seconds
# INFO: 	Extracting triples associated to R82
# INFO: 		Time extracting triples for property: 0.3952319622039795 seconds
# INFO: 	Extracting triples associated to R88
# INFO: 		Time extracting triples for property: 0.3685297966003418 seconds
# INFO: 	Extracting triples associated to R89
# INFO: 		Time extracting triples for property: 0.29855847358703613 seconds
# INFO: 	Extracting data property assertions
# INFO: 		Time extracting data property assertions: 0.0157320499420166 seconds
# INFO: 	Extracting complex equivalence axioms
# INFO: 		Time extracting complex equivalence axioms: 1777.8600461483002 seconds
# INFO: 	Extracting annotations.
# INFO: 		Time extracting annotations: 69.80106091499329 seconds
# INFO: Projection created into a Graph object (RDFlib library)
# INFO:
#
#
# Extraction time for ontologies:5427.57
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\users\sev_s\appdata\local\programs\python\python38\lib\site-packages\rdflib\namespace\__init__.py:478, in NamespaceManager.compute_qname_strict(self, uri, generate)
#     477 try:
# --> 478     namespace, name = split_uri(uri, NAME_START_CATEGORIES)
#     479 except ValueError as e:
#
# File c:\users\sev_s\appdata\local\programs\python\python38\lib\site-packages\rdflib\namespace\__init__.py:684, in split_uri(uri, split_start)
#     683         break
# --> 684 raise ValueError("Can't split '{}'".format(uri))
#
# ValueError: Can't split 'http://snomed.info/id/766939001'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 12
#       1 import owl2vec4mappings
#       3 # Parameters:
#       4 # ontology_file1
#       5 # ontology_file2
#    (...)
#      10 # mix_doc
#      11 # but there are some parameters you can change in config file
# ---> 12 gensim_model = owl2vec4mappings.extract_owl2vec_model(ontology_file1 = "./case_studies/Data/snomed.neoplas.owl",
#      13                                                 ontology_file2 = './case_studies/Data/ncit.neoplas.owl',
#      14                                                 mapping_file = './case_studies/Data/trainUnionS2NN.tsv',
#      15                                                 config_file = "./default1.cfg",
#      16                                                 uri_doc = True, lit_doc = True, mix_doc = True)
#
# File ~\Documents\OWL2Vec-Star\owl2vec4mappings.py:45, in extract_owl2vec_model(ontology_file1, ontology_file2, mapping_file, config_file, uri_doc, lit_doc, mix_doc)
#      42 if not os.path.exists(config['DOCUMENT']['cache_dir']):
#      43     os.mkdir(config['DOCUMENT']['cache_dir'])
# ---> 45 model_ = __perform_ontology_embedding(config)
#      47 return model_
#
# File ~\Documents\OWL2Vec-Star\owl2vec4mappings.py:108, in __perform_ontology_embedding(config)
#     104     logging.info(f'\n\n\nExtraction time for ontologies:{elapsed_time:.2f}')
#     106     projection = graph1 + graph2
# --> 108     projection.serialize(config['BASIC']['ontology_file'], format="xml")
#     109     projection = OntologyProjection(config['BASIC']['ontology_file'], reasoner=Reasoner.STRUCTURAL, only_taxonomy=False,
#     110                                 bidirectional_taxonomy=True, include_literals=True, avoid_properties=set(),
#     111                                 additional_preferred_labels_annotations=set(),
#     112                                 additional_synonyms_annotations=set(),
#     113                                 memory_reasoner='13351')
#     114 else:
#
# File c:\users\sev_s\appdata\local\programs\python\python38\lib\site-packages\rdflib\graph.py:1136, in Graph.serialize(self, destination, format, base, encoding, **args)
#    1134 fd, name = tempfile.mkstemp()
#    1135 stream = os.fdopen(fd, "wb")
# -> 1136 serializer.serialize(stream, base=base, encoding=encoding, **args)
#    1137 stream.close()
#    1138 dest = url2pathname(path) if scheme == "file" else location
#
# File c:\users\sev_s\appdata\local\programs\python\python38\lib\site-packages\rdflib\plugins\serializers\rdfxml.py:75, in XMLSerializer.serialize(self, stream, base, encoding, **args)
#      71     write('   xml:base="%s"\n' % self.base)
#      72 # TODO:
#      73 # assert(
#      74 #    namespaces["http://www.w3.org/1999/02/22-rdf-syntax-ns#"]=='rdf')
# ---> 75 bindings = list(self.__bindings())
#      76 bindings.sort()
#      78 for prefix, namespace in bindings:
#
# File c:\users\sev_s\appdata\local\programs\python\python38\lib\site-packages\rdflib\plugins\serializers\rdfxml.py:31, in XMLSerializer.__bindings(self)
#      28 bindings = {}
#      30 for predicate in set(store.predicates()):
# ---> 31     prefix, namespace, name = nm.compute_qname_strict(predicate)
#      32     bindings[prefix] = URIRef(namespace)
#      34 RDFNS = URIRef("http://www.w3.org/1999/02/22-rdf-syntax-ns#")
#
# File c:\users\sev_s\appdata\local\programs\python\python38\lib\site-packages\rdflib\namespace\__init__.py:484, in NamespaceManager.compute_qname_strict(self, uri, generate)
#     479 except ValueError as e:
#     480     message = (
#     481         "This graph cannot be serialized to a strict format "
#     482         "because there is no valid way to shorten {}".format(uri)
#     483     )
# --> 484     raise ValueError(message)
#     485     # omitted for strict since NCNames cannot be empty
#     486     # namespace = URIRef(uri)
#     487     # prefix = self.store.prefix(namespace)
#     488     # if not prefix:
#     489     # raise e
#     491 if namespace not in self.__strie:
#
# ValueError: This graph cannot be serialized to a strict format because there is no valid way to shorten http://snomed.info/id/766939001

# %%
# Run
import configparser
config = configparser.ConfigParser()
config.read("default1.cfg")
output_folder=config['DOCUMENT']['cache_dir']

# %%
#Gensim format
#Run
gensim_model.save(output_folder+"ontology"+'_'+config['DOCUMENT']['walk_depth']+".embeddings")

# %%
#Txt format
#Run
gensim_model.wv.save_word2vec_format(output_folder+"ontology"+'_'+config['DOCUMENT']['walk_depth']+".embeddings.txt", binary=False)

# %% [markdown]
# ## Loading embeddings and getting similarities

# %%
from gensim.models import KeyedVectors

#Embedding vectors generated above
model = KeyedVectors.load(output_folder+"ontology"+'_'+config['DOCUMENT']['walk_depth']+".embeddings", mmap='r')
wv = model.wv

vector = wv['committee']  # Get numpy vector of a word
print("Vector for 'committee'")
print(vector)
print()

#cosine similarity
similarity = wv.similarity('committee', 'http://conference#Committee')
print("Similarity between committee and http://conference#Committee", similarity)
print()

similarity = wv.similarity('http://conference#Reviewer', 'reviewer')
print(similarity)
print()

#Most similar cosine similarity
result = wv.most_similar(positive=['reviewer', 'committee'])
print(result)
print()

#Most similar entities: cosmul
result = wv.most_similar_cosmul(positive=['reviewer'])
print(result)
print()
# Out:
# INFO: loading Word2VecKeyedVectors object from ./caches_omim2ordo/ontology_3.embeddings
# INFO: loading wv recursively from ./caches_omim2ordo/ontology_3.embeddings.wv.* with mmap=r
# INFO: setting ignored attribute vectors_norm to None
# INFO: loading vocabulary recursively from ./caches_omim2ordo/ontology_3.embeddings.vocabulary.* with mmap=r
# INFO: loading trainables recursively from ./caches_omim2ordo/ontology_3.embeddings.trainables.* with mmap=r
# INFO: setting ignored attribute cum_table to None
# INFO: loaded ./caches_omim2ordo/ontology_3.embeddings
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 7
#       4 model = KeyedVectors.load(output_folder+"ontology"+'_'+config['DOCUMENT']['walk_depth']+".embeddings", mmap='r')
#       5 wv = model.wv
# ----> 7 vector = wv['committee']  # Get numpy vector of a word
#       8 print("Vector for 'committee'")
#       9 print(vector)
#
# File c:\users\sev_s\appdata\local\programs\python\python38\lib\site-packages\gensim\models\keyedvectors.py:353, in BaseKeyedVectors.__getitem__(self, entities)
#     338 """Get vector representation of `entities`.
#     339
#     340 Parameters
#    (...)
#     349
#     350 """
#     351 if isinstance(entities, string_types):
#     352     # allow calls like trained_model['office'], as a shorthand for trained_model[['office']]
# --> 353     return self.get_vector(entities)
#     355 return vstack([self.get_vector(entity) for entity in entities])
#
# File c:\users\sev_s\appdata\local\programs\python\python38\lib\site-packages\gensim\models\keyedvectors.py:471, in WordEmbeddingsKeyedVectors.get_vector(self, word)
#     470 def get_vector(self, word):
# --> 471     return self.word_vec(word)
#
# File c:\users\sev_s\appdata\local\programs\python\python38\lib\site-packages\gensim\models\keyedvectors.py:468, in WordEmbeddingsKeyedVectors.word_vec(self, word, use_norm)
#     466     return result
#     467 else:
# --> 468     raise KeyError("word '%s' not in vocabulary" % word)
#
# KeyError: "word 'committee' not in vocabulary"

# %%
# Run
from gensim.models import Word2Vec
model = Word2Vec.load(output_folder+"ontology"+'_'+config['DOCUMENT']['walk_depth']+".embeddings")

# %%
# Run
ranking_results = []
# save the scored candidate mappings in the same format as the original test.cands.tsv
f = open("scored.test.cands.tsv", "w")
f.write("SrcEntity" +'\t'+ "TgtEntity" +'\t'+ "TgtCandidates\n")
file = open(r"C:\Users\sev_s\Documents\OWL2Vec-Star\case_studies\Data\ncit2doid20223_test.cands.tsv")

for i in file.readlines()[1:]:
    src_ref_class = i.split('\t')[0]
    tgt_ref_class = i.split('\t')[1]
    tgt_cands = i.split('\t')[2]
    # print(src_ref_class, tgt_ref_class, tgt_cands)
    tgt_cands = eval(tgt_cands)  # transform string into list or sequence
    scored_cands = []
    for tgt_cand in tgt_cands:
        # assign a score to each candidate with an OM system
        try:
            matching_score = model.wv.similarity(src_ref_class, tgt_cand)
        except:
            matching_score = 0
        scored_cands.append([tgt_cand, matching_score])
    ranking_results.append([src_ref_class, tgt_ref_class, scored_cands])
    f.write(f'{src_ref_class}\t{tgt_ref_class}\t{scored_cands}\n')
print("done")

# %%
# Run
import numpy as np
distance_results = []
# save the scored candidate mappings in the same format as the original test.cands.tsv
f = open("distance.test.cands.tsv", "w")
f.write("SrcEntity" +'\t'+ "TgtEntity" +'\t'+ "TgtCandidates\n")
file = open(r"C:\Users\sev_s\Documents\OWL2Vec-Star\case_studies\Data\ncit2doid20223_test.cands.tsv")

for i in file.readlines()[1:]:
    src_ref_class = i.split('\t')[0]
    tgt_ref_class = i.split('\t')[1]
    tgt_cands = i.split('\t')[2]
    # print(src_ref_class, tgt_ref_class, tgt_cands)
    tgt_cands = eval(tgt_cands)  # transform string into list or sequence
    scored_cands = []
    for tgt_cand in tgt_cands:
        # assign a score to each candidate with an OM system
        try:
            euc_dist = np.linalg.norm(model.wv[src_ref_class] - model.wv[tgt_cand])
        except:
            euc_dist = np.inf
        scored_cands.append([tgt_cand, euc_dist])
    distance_results.append([src_ref_class, tgt_ref_class, scored_cands])
    f.write(f'{src_ref_class}\t{tgt_ref_class}\t{scored_cands}\n')
print("done")

# %%
# Run
from gensim.models import Word2Vec
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import numpy as np
import matplotlib.pyplot as plt

# Load your Word2Vec model
model = Word2Vec.load(output_folder+"ontology"+'_'+config['DOCUMENT']['walk_depth']+".embeddings")

# Extract word vectors and corresponding words
words = list(model.wv.vocab.keys())
vectors = [model.wv[word] for word in words]

# Apply PCA to reduce dimensionality
num_dimensions = 2
pca = PCA(n_components=num_dimensions)
vectors_pca = pca.fit_transform(vectors)

# Elbow method for finding number of clusters

wcss = [] 
for i in range(1, 16): 
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(vectors_pca) 
    wcss.append(kmeans.inertia_)

plt.plot(range(1,16), wcss)

# %%
# Apply KMeans clustering
num_clusters = 5  # You can change this based on your preference
kmeans = KMeans(n_clusters=num_clusters)
kmeans.fit(vectors_pca)

# Visualize the clusters
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']
for i in range(num_clusters):
    cluster_points = np.array([vectors_pca[j] for j in range(len(words)) if kmeans.labels_[j] == i])
    plt.scatter(cluster_points[:, 0], cluster_points[:, 1], c=colors[i], label=f'Cluster {i + 1}')

plt.title('Train-Val+ AML union LOgmap')
plt.legend()
plt.show()

# %%
import random

# Choose a random index within the range of the words list
random_index = random.sample(range(len(words)), 30)

vector = {
    'X':vectors_pca[:,0],
    'Y':vectors_pca[:,1],
    'words': np.array(words),
    'label':kmeans.labels_
}

sample_vectors_pca = np.array([vector['X'][random_index], vector['Y'][random_index]]).T
sample_words = np.array(vector['words'][random_index])
sample_cluster = np.array(vector['label'][random_index])

# Visualize the clusters
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']
markers = ['o', 'v', '^', '<', '>', 's', 'p', 'h', 'x', '+', 'd', '|', '_']

for i in range(num_clusters):
    cluster_points = np.array([sample_vectors_pca[j] for j in range(len(sample_words)) if sample_cluster[j] == i])
    plt.scatter(cluster_points[:,0], cluster_points[:,1], c=colors[i], marker=markers[i])

for i, txt in enumerate(sample_words):
    plt.annotate(txt, (sample_vectors_pca[i,0], sample_vectors_pca[i,1]), fontsize=5)
