# %% [markdown]
# # Owl2vec_star_ext
# In this process, we get ontology files and to change it to embedding model

# %%
import owl2vec4mappings

# Parameters:
# ontology_file1
# ontology_file2
# mapping_file
# config_file
# uri_doc
# lit_doc
# mix_doc
# but there are some parameters you can change in config file
gensim_model = owl2vec4mappings.extract_owl2vec_model(ontology_file1 = "./case_studies/alignment/Data/ordo.owl",
                                                ontology_file2 = './case_studies/alignment/Data/omim.owl',
                                                mapping_file = './case_studies/alignment/Data/omim2ordo2022.train+val_Int.tsv',
                                                config_file = "./dfl2022.cfg",
                                                uri_doc = True, lit_doc = True, mix_doc = True)
# Out:
# * Owlready2 * Warning: optimized Cython parser module 'owlready2_optimized' is not available, defaulting to slower Python implementation
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sev_s\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# INFO: 1
# INFO:
# Generate URI document ...
# INFO: Experiment results:
#
# INFO: Number of nodes 4977
# INFO: Mean of mean hops: 4.00
# INFO: Mean Time walks taken by the 1 process: 55.3762126 seconds
# INFO: Mean of percentage of visited nodes in ontology  1: 29.24%
# INFO: Mean of percentage of visited nodes in ontology  2: 29.24%
#
# INFO: Visited nodes with numbers {'http://www.semanticweb.org/owl2vec#superClassOf': 6283948, 'http://www.w3.org/2000/01/rdf-schema#label': 18046, 'http://www.w3.org/2000/01/rdf-schema#subClassOf': 13015, 'http://www.ebi.ac.uk/efo/alternative_term': 7833, 'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 7314, '=': 5726, 'http://www.orpha.net/ORDO/Orphanet_377788': 2454, 'http://www.orpha.net/ORDO/Orphanet_377789': 1220, 'http://www.orpha.net/ORDO/Orphanet_377794': 322, 'http://www.orpha.net/ORDO/Orphanet_377796': 250, 'http://www.omim.org/phenotypicSeries/PS118220': 120, 'http://www.orpha.net/ORDO/Orphanet_377791': 116, 'http://www.omim.org/phenotypicSeries/PS303350': 86, 'http://www.omim.org/phenotypicSeries/PS164400': 76, 'http://www.omim.org/phenotypicSeries/PS251200': 52, 'http://www.omim.org/phenotypicSeries/PS266600': 51, 'http://www.omim.org/phenotypicSeries/PS609060': 50, 'http://www.orpha.net/ORDO/Orphanet_377795': 50, 'http://www.omim.org/phenotypicSeries/PS253600': 39, 'http://www.omim.org/phenotypicSeries/PS311360': 37, 'http://www.omim.org/phenotypicSeries/PS608583': 37, 'http://www.omim.org/phenotypicSeries/PS212065': 34, 'http://www.omim.org/phenotypicSeries/PS601462': 33, 'http://www.omim.org/phenotypicSeries/PS256100': 33, 'http://www.omim.org/phenotypicSeries/PS212066': 32, 'http://www.omim.org/phenotypicSeries/PS213200': 32, 'http://www.omim.org/phenotypicSeries/PS242300': 29, 'http://www.omim.org/phenotypicSeries/PS192500': 29, 'http://www.omim.org/phenotypicSeries/PS309510': 26, 'http://www.omim.org/phenotypicSeries/PS128100': 26, 'http://www.omim.org/phenotypicSeries/PS107970': 26, 'http://www.omim.org/phenotypicSeries/PS253310': 25, 'http://www.omim.org/phenotypicSeries/PS607014': 24, 'http://www.omim.org/phenotypicSeries/PS163950': 24, 'http://www.omim.org/phenotypicSeries/PS130000': 23, 'http://www.omim.org/phenotypicSeries/PS254800': 21, 'http://www.omim.org/phenotypicSeries/PS203100': 21, 'http://www.omim.org/phenotypicSeries/PS148300': 21, 'http://www.omim.org/phenotypicSeries/PS607426': 21, 'http://www.omim.org/phenotypicSeries/PS202700': 21, 'http://www.omim.org/phenotypicSeries/PS311200': 20, 'http://www.omim.org/phenotypicSeries/PS136800': 19, 'http://www.omim.org/phenotypicSeries/PS193000': 19, 'http://www.omim.org/phenotypicSeries/PS600512': 19, 'http://www.omim.org/phenotypicSeries/PS305100': 18, 'http://www.omim.org/phenotypicSeries/PS162400': 17, 'http://www.omim.org/phenotypicSeries/PS601495': 17, 'http://www.omim.org/phenotypicSeries/PS104500': 17, 'http://www.omim.org/phenotypicSeries/PS256450': 17, 'http://www.omim.org/phenotypicSeries/PS184255': 17, 'http://www.omim.org/phenotypicSeries/PS300755': 16, 'http://www.omim.org/phenotypicSeries/PS601764': 15, 'http://www.omim.org/phenotypicSeries/PS123700': 15, 'http://www.omim.org/phenotypicSeries/PS132400': 15, 'http://www.omim.org/phenotypicSeries/PS310300': 15, 'http://www.omim.org/phenotypicSeries/PS235400': 15, 'http://www.omim.org/phenotypicSeries/PS151660': 15, 'http://www.orpha.net/ORDO/Orphanet_68385': 14, 'http://www.omim.org/phenotypicSeries/PS109720': 13, 'http://www.omim.org/phenotypicSeries/PS600513': 13, 'http://www.omim.org/phenotypicSeries/PS268310': 13, 'http://www.omim.org/phenotypicSeries/PS603511': 13, 'http://www.omim.org/phenotypicSeries/PS131760': 13, 'http://www.omim.org/phenotypicSeries/PS226400': 13, 'http://www.omim.org/phenotypicSeries/PS312170': 13, 'http://www.omim.org/phenotypicSeries/PS126200': 13, 'http://www.omim.org/phenotypicSeries/PS607765': 12, 'http://www.omim.org/phenotypicSeries/PS607596': 12, 'http://www.omim.org/phenotypicSeries/PS160120': 11, 'http://www.omim.org/phenotypicSeries/PS601419': 11, 'http://www.omim.org/phenotypicSeries/PS309800': 11, 'http://www.omim.org/phenotypicSeries/PS215100': 11, 'http://www.omim.org/phenotypicSeries/PS606215': 11, 'http://www.omim.org/phenotypicSeries/PS115210': 11, 'http://www.omim.org/phenotypicSeries/PS202200': 11, 'http://www.omim.org/phenot ...
#
# INFO: Coverage nodes 29.24
#
#
# INFO: Extracted 31567 walks for 4977 seed entities
# INFO: Extracted 2 axiom sentences
# INFO:
# Generate literal document ...
# INFO: Extracted 28842 annotation sentences
# INFO:
# Generate mixture document ...
# INFO: URI_Doc: 31569, Lit_Doc: 60411, Mix_Doc: 31569
# INFO: Time for document construction: 67.65041327476501 seconds
# INFO:
# Train the embedding model ...
# INFO: collecting all words and their counts
# INFO: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO: PROGRESS: at sentence #10000, processed 50057 words, keeping 13468 word types
# INFO: PROGRESS: at sentence #20000, processed 100032 words, keeping 21295 word types
# INFO: PROGRESS: at sentence #30000, processed 149999 words, keeping 27098 word types
# INFO: PROGRESS: at sentence #40000, processed 200104 words, keeping 31765 word types
# INFO: PROGRESS: at sentence #50000, processed 250205 words, keeping 35710 word types
# INFO: PROGRESS: at sentence #60000, processed 300168 words, keeping 39170 word types
# INFO: PROGRESS: at sentence #70000, processed 350144 words, keeping 42168 word types
# INFO: PROGRESS: at sentence #80000, processed 399997 words, keeping 44796 word types
# INFO: PROGRESS: at sentence #90000, processed 450382 words, keeping 47207 word types
# INFO: PROGRESS: at sentence #100000, processed 500805 words, keeping 49540 word types
# INFO: PROGRESS: at sentence #110000, processed 550693 words, keeping 51637 word types
# INFO: PROGRESS: at sentence #120000, processed 600939 words, keeping 53527 word types
# INFO: collected 54170 word types from a corpus of 618714 raw words and 123549 sentences
# INFO: Loading a fresh vocabulary
# INFO: effective_min_count=1 retains 54170 unique words (100% of original 54170, drops 0)
# INFO: effective_min_count=1 leaves 618714 word corpus (100% of original 618714, drops 0)
# INFO: deleting the raw counts dictionary of 54170 items
# INFO: sample=0.001 downsamples 29 most-common words
# INFO: downsampling leaves estimated 377248 word corpus (61.0% of prior 618714)
# INFO: estimated required memory for 54170 words and 100 dimensions: 70421000 bytes
# INFO: resetting layer weights
# INFO: training model with 8 workers on 54170 vocabulary and 100 features, using sg=1 hs=0 sample=0.001 negative=25 window=5
# INFO: worker thread finished; awaiting finish of 7 more threads
# INFO: EPOCH 1 - PROGRESS: at 90.51% examples, 339928 words/s, in_qsize 6, out_qsize 1
# INFO: worker thread finished; awaiting finish of 6 more threads
# INFO: worker thread finished; awaiting finish of 5 more threads
# INFO: worker thread finished; awaiting finish of 4 more threads
# INFO: worker thread finished; awaiting finish of 3 more threads
# INFO: worker thread finished; awaiting finish of 2 more threads
# INFO: worker thread finished; awaiting finish of 1 more threads
# INFO: worker thread finished; awaiting finish of 0 more threads
# INFO: EPOCH - 1 : training on 618714 raw words (377263 effective words) took 1.1s, 355060 effective words/s
# INFO: EPOCH 2 - PROGRESS: at 82.42% examples, 304390 words/s, in_qsize 11, out_qsize 0
# INFO: worker thread finished; awaiting finish of 7 more threads
# INFO: worker thread finished; awaiting finish of 6 more threads
# INFO: worker thread finished; awaiting finish of 5 more threads
# INFO: worker thread finished; awaiting finish of 4 more threads
# INFO: worker thread finished; awaiting finish of 3 more threads
# INFO: worker thread finished; awaiting finish of 2 more threads
# INFO: worker thread finished; awaiting finish of 1 more threads
# INFO: worker thread finished; awaiting finish of 0 more threads
# INFO: EPOCH - 2 : training on 618714 raw words (377181 effective words) took 1.2s, 327557 effective words/s
# INFO: worker thread finished; awaiting finish of 7 more threads
# INFO: EPOCH 3 - PROGRESS: at 90.51% examples, 341021 words/s, in_qsize 6, out_qsize 1
# INFO: worker thread finished; awaiting finish of 6 more threads
# INFO: worker thread finished; awaiting finish of 5 more threads
# INFO: worker thread finished; awaiting finish of 4 more threads
# INFO: worker thread finished; awaiting finish of 3 more threads
# INFO: worker thread finished; awaiting finish of 2 more threads
# INFO: worker thread finished; awaiting finish of 1 more threads
# INFO: worker thread finished; awaiting finish of 0 more threads
# INFO: EPOCH - 3 : training on 618714 raw words (377389 effective words) took 1.1s, 347524 effective words/s
# INFO: EPOCH 4 - PROGRESS: at 87.28% examples, 318951 words/s, in_qsize 8, out_qsize 0
# INFO: worker thread finished; awaiting finish of 7 more threads
# INFO: worker thread finished; awaiting finish of 6 more threads
# INFO: worker thread finished; awaiting finish of 5 more threads
# INFO: worker thread finished; awaiting finish of 4 more threads
# INFO: worker thread finished; awaiting finish of 3 more threads
# INFO: worker thread finished; awaiting finish of 2 more threads
# INFO: worker thread finished; awaiting finish of 1 more threads
# INFO: worker thread finished; awaiting finish of 0 more threads
# INFO: EPOCH - 4 : training on 618714 raw words (377535 effective words) took 1.1s, 338057 effective words/s
# INFO: EPOCH 5 - PROGRESS: at 87.28% examples, 328294 words/s, in_qsize 7, out_qsize 2
# INFO: worker thread finished; awaiting finish of 7 more threads
# INFO: worker thread finished; awaiting finish of 6 more threads
# INFO: worker thread finished; awaiting finish of 5 more threads
# INFO: worker thread finished; awaiting finish of 4 more threads
# INFO: worker thread finished; awaiting finish of 3 more threads
# INFO: worker thread finished; awaiting finish of 2 more threads
# INFO: worker thread finished; awaiting finish of 1 more threads
# INFO: worker thread finished; awaiting finish of 0 more threads
# INFO: EPOCH - 5 : training on 618714 raw words (377149 effective words) took 1.1s, 346172 effective words/s
# INFO: EPOCH 6 - PROGRESS: at 84.03% examples, 314031 words/s, in_qsize 10, out_qsize 0
# INFO: worker thread finished; awaiting finish of 7 more threads
# INFO: worker thread finished; awaiting finish of 6 more threads
# INFO: worker thread finished; awaiting finish of 5 more threads
# INFO: worker thread finished; awaiting finish of 4 more threads
# INFO: worker thread finished; awaiting finish of 3 more threads
# INFO: worker thread finished; awaiting finish of 2 more threads
# INFO: worker thread finished; awaiting finish of 1 more threads
# INFO: worker thread finished; awaiting finish of 0 more threads
# INFO: EPOCH - 6 : training on 618714 raw words (377439 effective words) took 1.1s, 339427 effective words/s
# INFO: worker thread finished; awaiting finish of 7 more threads
# INFO: EPOCH 7 - PROGRESS: at 90.51% examples, 340529 words/s, in_qsize 6, out_qsize 1
# INFO: worker thread finished; awaiting finish of 6 more threads
# INFO: worker thread finished; awaiting finish of 5 more threads
# INFO: worker thread finished; awaiting finish of 4 more threads
# INFO: worker thread finished; awaiting finish of 3 more threads
# INFO: worker thread finished; awaiting finish of 2 more threads
# INFO: worker thread finished; awaiting finish of 1 more threads
# INFO: worker thread finished; awaiting finish of 0 more threads
# INFO: EPOCH - 7 : training on 618714 raw words (377175 effective words) took 1.1s, 344530 effective words/s
# INFO: EPOCH 8 - PROGRESS: at 79.21% examples, 294028 words/s, in_qsize 13, out_qsize 0
# INFO: worker thread finished; awaiting finish of 7 more threads
# INFO: worker thread finished; awaiting finish of 6 more threads
# INFO: worker thread finished; awaiting finish of 5 more threads
# INFO: worker thread finished; awaiting finish of 4 more threads
# INFO: worker thread finished; awaiting finish of 3 more threads
# INFO: worker thread finished; awaiting finish of 2 more threads
# INFO: worker thread finished; awaiting finish of 1 more threads
# INFO: worker thread finished; awaiting finish of 0 more threads
# INFO: EPOCH - 8 : training on 618714 raw words (377079 effective words) took 1.1s, 328497 effective words/s
# INFO: EPOCH 9 - PROGRESS: at 87.30% examples, 328153 words/s, in_qsize 8, out_qsize 0
# INFO: worker thread finished; awaiting finish of 7 more threads
# INFO: worker thread finished; awaiting finish of 6 more threads
# INFO: worker thread finished; awaiting finish of 5 more threads
# INFO: worker thread finished; awaiting finish of 4 more threads
# INFO: worker thread finished; awaiting finish of 3 more threads
# INFO: worker thread finished; awaiting finish of 2 more threads
# INFO: worker thread finished; awaiting finish of 1 more threads
# INFO: worker thread finished; awaiting finish of 0 more threads
# INFO: EPOCH - 9 : training on 618714 raw words (377241 effective words) took 1.1s, 350172 effective words/s
# INFO: EPOCH 10 - PROGRESS: at 85.68% examples, 320519 words/s, in_qsize 9, out_qsize 0
# INFO: worker thread finished; awaiting finish of 7 more threads
# INFO: worker thread finished; awaiting finish of 6 more threads
# INFO: worker thread finished; awaiting finish of 5 more threads
# INFO: worker thread finished; awaiting finish of 4 more threads
# INFO: worker thread finished; awaiting finish of 3 more threads
# INFO: worker thread finished; awaiting finish of 2 more threads
# INFO: worker thread finished; awaiting finish of 1 more threads
# INFO: worker thread finished; awaiting finish of 0 more threads
# INFO: EPOCH - 10 : training on 618714 raw words (377439 effective words) took 1.1s, 337083 effective words/s
# INFO: EPOCH 11 - PROGRESS: at 85.66% examples, 313448 words/s, in_qsize 9, out_qsize 0
# INFO: worker thread finished; awaiting finish of 7 more threads
# INFO: worker thread finished; awaiting finish of 6 more threads
# INFO: worker thread finished; awaiting finish of 5 more threads
# INFO: worker thread finished; awaiting finish of 4 more threads
# INFO: worker thread finished; awaiting finish of 3 more threads
# INFO: worker thread finished; awaiting finish of 2 more threads
# INFO: worker thread finished; awaiting finish of 1 more threads
# INFO: worker thread finished; awaiting finish of 0 more threads
# INFO: EPOCH - 11 : training on 618714 raw words (377150 effective words) took 1.1s, 338198 effective words/s
# INFO: EPOCH 12 - PROGRESS: at 87.28% examples, 326080 words/s, in_qsize 8, out_qsize 0
# INFO: worker thread finished; awaiting finish of 7 more threads
# INFO: worker thread finished; awaiting finish of 6 more threads
# INFO: worker thread finished; awaiting finish of 5 more threads
# INFO: worker thread finished; awaiting finish of 4 more threads
# INFO: worker thread finished; awaiting finish of 3 more threads
# INFO: worker thread finished; awaiting finish of 2 more threads
# INFO: worker thread finished; awaiting finish of 1 more threads
# INFO: worker thread finished; awaiting finish of 0 more threads
# INFO: EPOCH - 12 : training on 618714 raw words (377152 effective words) took 1.1s, 347252 effective words/s
# INFO: worker thread finished; awaiting finish of 7 more threads
# INFO: worker thread finished; awaiting finish of 6 more threads
# INFO: worker thread finished; awaiting finish of 5 more threads
# INFO: worker thread finished; awaiting finish of 4 more threads
# INFO: worker thread finished; awaiting finish of 3 more threads
# INFO: worker thread finished; awaiting finish of 2 more threads
# INFO: EPOCH 13 - PROGRESS: at 98.58% examples, 366596 words/s, in_qsize 1, out_qsize 1
# INFO: worker thread finished; awaiting finish of 1 more threads
# INFO: worker thread finished; awaiting finish of 0 more threads
# INFO: EPOCH - 13 : training on 618714 raw words (377278 effective words) took 1.0s, 369462 effective words/s
# INFO: EPOCH 14 - PROGRESS: at 88.90% examples, 333220 words/s, in_qsize 7, out_qsize 1
# INFO: worker thread finished; awaiting finish of 7 more threads
# INFO: worker thread finished; awaiting finish of 6 more threads
# INFO: worker thread finished; awaiting finish of 5 more threads
# INFO: worker thread finished; awaiting finish of 4 more threads
# INFO: worker thread finished; awaiting finish of 3 more threads
# INFO: worker thread finished; awaiting finish of 2 more threads
# INFO: worker thread finished; awaiting finish of 1 more threads
# INFO: worker thread finished; awaiting finish of 0 more threads
# INFO: EPOCH - 14 : training on 618714 raw words (376994 effective words) took 1.1s, 345212 effective words/s
# INFO: EPOCH 15 - PROGRESS: at 88.89% examples, 332508 words/s, in_qsize 7, out_qsize 1
# INFO: worker thread finished; awaiting finish of 7 more threads
# INFO: worker thread finished; awaiting finish of 6 more threads
# INFO: worker thread finished; awaiting finish of 5 more threads
# INFO: worker thread finished; awaiting finish of 4 more threads
# INFO: worker thread finished; awaiting finish of 3 more threads
# INFO: worker thread finished; awaiting finish of 2 more threads
# INFO: worker thread finished; awaiting finish of 1 more threads
# INFO: worker thread finished; awaiting finish of 0 more threads
# INFO: EPOCH - 15 : training on 618714 raw words (377163 effective words) took 1.1s, 346394 effective words/s
# INFO: EPOCH 16 - PROGRESS: at 84.06% examples, 313006 words/s, in_qsize 9, out_qsize 1
# INFO: worker thread finished; awaiting finish of 7 more threads
# INFO: worker thread finished; awaiting finish of 6 more threads
# INFO: worker thread finished; awaiting finish of 5 more threads
# INFO: worker thread finished; awaiting finish of 4 more threads
# INFO: worker thread finished; awaiting finish of 3 more threads
# INFO: worker thread finished; awaiting finish of 2 more threads
# INFO: worker thread finished; awaiting finish of 1 more threads
# INFO: worker thread finished; awaiting finish of 0 more threads
# INFO: EPOCH - 16 : training on 618714 raw words (377141 effective words) took 1.1s, 342331 effective words/s
# INFO: EPOCH 17 - PROGRESS: at 87.28% examples, 324902 words/s, in_qsize 8, out_qsize 0
# INFO: worker thread finished; awaiting finish of 7 more threads
# INFO: worker thread finished; awaiting finish of 6 more threads
# INFO: worker thread finished; awaiting finish of 5 more threads
# INFO: worker thread finished; awaiting finish of 4 more threads
# INFO: worker thread finished; awaiting finish of 3 more threads
# INFO: worker thread finished; awaiting finish of 2 more threads
# INFO: worker thread finished; awaiting finish of 1 more threads
# INFO: worker thread finished; awaiting finish of 0 more threads
# INFO: EPOCH - 17 : training on 618714 raw words (377201 effective words) took 1.1s, 344826 effective words/s
# INFO: EPOCH 18 - PROGRESS: at 85.68% examples, 321984 words/s, in_qsize 9, out_qsize 0
# INFO: worker thread finished; awaiting finish of 7 more threads
# INFO: worker thread finished; awaiting finish of 6 more threads
# INFO: worker thread finished; awaiting finish of 5 more threads
# INFO: worker thread finished; awaiting finish of 4 more threads
# INFO: worker thread finished; awaiting finish of 3 more threads
# INFO: worker thread finished; awaiting finish of 2 more threads
# INFO: worker thread finished; awaiting finish of 1 more threads
# INFO: worker thread finished; awaiting finish of 0 more threads
# INFO: EPOCH - 18 : training on 618714 raw words (377557 effective words) took 1.1s, 343450 effective words/s
# INFO: EPOCH 19 - PROGRESS: at 84.05% examples, 314044 words/s, in_qsize 10, out_qsize 0
# INFO: worker thread finished; awaiting finish of 7 more threads
# INFO: worker thread finished; awaiting finish of 6 more threads
# INFO: worker thread finished; awaiting finish of 5 more threads
# INFO: worker thread finished; awaiting finish of 4 more threads
# INFO: worker thread finished; awaiting finish of 3 more threads
# INFO: worker thread finished; awaiting finish of 2 more threads
# INFO: worker thread finished; awaiting finish of 1 more threads
# INFO: worker thread finished; awaiting finish of 0 more threads
# INFO: EPOCH - 19 : training on 618714 raw words (376919 effective words) took 1.1s, 338669 effective words/s
# INFO: worker thread finished; awaiting finish of 7 more threads
# INFO: worker thread finished; awaiting finish of 6 more threads
# INFO: EPOCH 20 - PROGRESS: at 92.12% examples, 342719 words/s, in_qsize 5, out_qsize 1
# INFO: worker thread finished; awaiting finish of 5 more threads
# INFO: worker thread finished; awaiting finish of 4 more threads
# INFO: worker thread finished; awaiting finish of 3 more threads
# INFO: worker thread finished; awaiting finish of 2 more threads
# INFO: worker thread finished; awaiting finish of 1 more threads
# INFO: worker thread finished; awaiting finish of 0 more threads
# INFO: EPOCH - 20 : training on 618714 raw words (377063 effective words) took 1.1s, 352549 effective words/s
# INFO: worker thread finished; awaiting finish of 7 more threads
# INFO: worker thread finished; awaiting finish of 6 more threads
# INFO: worker thread finished; awaiting finish of 5 more threads
# INFO: worker thread finished; awaiting finish of 4 more threads
# INFO: worker thread finished; awaiting finish of 3 more threads
# INFO: worker thread finished; awaiting finish of 2 more threads
# INFO: worker thread finished; awaiting finish of 1 more threads
# INFO: worker thread finished; awaiting finish of 0 more threads
# INFO: EPOCH - 21 : training on 618714 raw words (377393 effective words) took 1.0s, 378754 effective words/s
# INFO: EPOCH 22 - PROGRESS: at 88.90% examples, 333928 words/s, in_qsize 7, out_qsize 1
# INFO: worker thread finished; awaiting finish of 7 more threads
# INFO: worker thread finished; awaiting finish of 6 more threads
# INFO: worker thread finished; awaiting finish of 5 more threads
# INFO: worker thread finished; awaiting finish of 4 more threads
# INFO: worker thread finished; awaiting finish of 3 more threads
# INFO: worker thread finished; awaiting finish of 2 more threads
# INFO: worker thread finished; awaiting finish of 1 more threads
# INFO: worker thread finished; awaiting finish of 0 more threads
# INFO: EPOCH - 22 : training on 618714 raw words (376909 effective words) took 1.1s, 351057 effective words/s
# INFO: EPOCH 23 - PROGRESS: at 88.90% examples, 326504 words/s, in_qsize 7, out_qsize 1
# INFO: worker thread finished; awaiting finish of 7 more threads
# INFO: worker thread finished; awaiting finish of 6 more threads
# INFO: worker thread finished; awaiting finish of 5 more threads
# INFO: worker thread finished; awaiting finish of 4 more threads
# INFO: worker thread finished; awaiting finish of 3 more threads
# INFO: worker thread finished; awaiting finish of 2 more threads
# INFO: worker thread finished; awaiting finish of 1 more threads
# INFO: worker thread finished; awaiting finish of 0 more threads
# INFO: EPOCH - 23 : training on 618714 raw words (377270 effective words) took 1.1s, 347459 effective words/s
# INFO: EPOCH 24 - PROGRESS: at 87.30% examples, 323659 words/s, in_qsize 8, out_qsize 0
# INFO: worker thread finished; awaiting finish of 7 more threads
# INFO: worker thread finished; awaiting finish of 6 more threads
# INFO: worker thread finished; awaiting finish of 5 more threads
# INFO: worker thread finished; awaiting finish of 4 more threads
# INFO: worker thread finished; awaiting finish of 3 more threads
# INFO: worker thread finished; awaiting finish of 2 more threads
# INFO: worker thread finished; awaiting finish of 1 more threads
# INFO: worker thread finished; awaiting finish of 0 more threads
# INFO: EPOCH - 24 : training on 618714 raw words (377262 effective words) took 1.1s, 342891 effective words/s
# INFO: worker thread finished; awaiting finish of 7 more threads
# INFO: EPOCH 25 - PROGRESS: at 90.51% examples, 339619 words/s, in_qsize 6, out_qsize 1
# INFO: worker thread finished; awaiting finish of 6 more threads
# INFO: worker thread finished; awaiting finish of 5 more threads
# INFO: worker thread finished; awaiting finish of 4 more threads
# INFO: worker thread finished; awaiting finish of 3 more threads
# INFO: worker thread finished; awaiting finish of 2 more threads
# INFO: worker thread finished; awaiting finish of 1 more threads
# INFO: worker thread finished; awaiting finish of 0 more threads
# INFO: EPOCH - 25 : training on 618714 raw words (377213 effective words) took 1.1s, 342213 effective words/s
# INFO: worker thread finished; awaiting finish of 7 more threads
# INFO: worker thread finished; awaiting finish of 6 more threads
# INFO: worker thread finished; awaiting finish of 5 more threads
# INFO: worker thread finished; awaiting finish of 4 more threads
# INFO: worker thread finished; awaiting finish of 3 more threads
# INFO: worker thread finished; awaiting finish of 2 more threads
# INFO: EPOCH 26 - PROGRESS: at 98.38% examples, 368489 words/s, in_qsize 1, out_qsize 1
# INFO: worker thread finished; awaiting finish of 1 more threads
# INFO: worker thread finished; awaiting finish of 0 more threads
# INFO: EPOCH - 26 : training on 618714 raw words (377270 effective words) took 1.0s, 373649 effective words/s
# INFO: worker thread finished; awaiting finish of 7 more threads
# INFO: worker thread finished; awaiting finish of 6 more threads
# INFO: worker thread finished; awaiting finish of 5 more threads
# INFO: worker thread finished; awaiting finish of 4 more threads
# INFO: EPOCH 27 - PROGRESS: at 95.34% examples, 359552 words/s, in_qsize 3, out_qsize 1
# INFO: worker thread finished; awaiting finish of 3 more threads
# INFO: worker thread finished; awaiting finish of 2 more threads
# INFO: worker thread finished; awaiting finish of 1 more threads
# INFO: worker thread finished; awaiting finish of 0 more threads
# INFO: EPOCH - 27 : training on 618714 raw words (377184 effective words) took 1.0s, 366443 effective words/s
# INFO: EPOCH 28 - PROGRESS: at 88.89% examples, 334485 words/s, in_qsize 7, out_qsize 1
# INFO: worker thread finished; awaiting finish of 7 more threads
# INFO: worker thread finished; awaiting finish of 6 more threads
# INFO: worker thread finished; awaiting finish of 5 more threads
# INFO: worker thread finished; awaiting finish of 4 more threads
# INFO: worker thread finished; awaiting finish of 3 more threads
# INFO: worker thread finished; awaiting finish of 2 more threads
# INFO: worker thread finished; awaiting finish of 1 more threads
# INFO: worker thread finished; awaiting finish of 0 more threads
# INFO: EPOCH - 28 : training on 618714 raw words (377067 effective words) took 1.1s, 353370 effective words/s
# INFO: worker thread finished; awaiting finish of 7 more threads
# INFO: EPOCH 29 - PROGRESS: at 90.51% examples, 335211 words/s, in_qsize 6, out_qsize 1
# INFO: worker thread finished; awaiting finish of 6 more threads
# INFO: worker thread finished; awaiting finish of 5 more threads
# INFO: worker thread finished; awaiting finish of 4 more threads
# INFO: worker thread finished; awaiting finish of 3 more threads
# INFO: worker thread finished; awaiting finish of 2 more threads
# INFO: worker thread finished; awaiting finish of 1 more threads
# INFO: worker thread finished; awaiting finish of 0 more threads
# INFO: EPOCH - 29 : training on 618714 raw words (377059 effective words) took 1.1s, 351678 effective words/s
# INFO: EPOCH 30 - PROGRESS: at 88.90% examples, 329892 words/s, in_qsize 7, out_qsize 1
# INFO: worker thread finished; awaiting finish of 7 more threads
# INFO: worker thread finished; awaiting finish of 6 more threads
# INFO: worker thread finished; awaiting finish of 5 more threads
# INFO: worker thread finished; awaiting finish of 4 more threads
# INFO: worker thread finished; awaiting finish of 3 more threads
# INFO: worker thread finished; awaiting finish of 2 more threads
# INFO: worker thread finished; awaiting finish of 1 more threads
# INFO: worker thread finished; awaiting finish of 0 more threads
# INFO: EPOCH - 30 : training on 618714 raw words (376922 effective words) took 1.1s, 347580 effective words/s
# INFO: EPOCH 31 - PROGRESS: at 87.28% examples, 326507 words/s, in_qsize 8, out_qsize 0
# INFO: worker thread finished; awaiting finish of 7 more threads
# INFO: worker thread finished; awaiting finish of 6 more threads
# INFO: worker thread finished; awaiting finish of 5 more threads
# INFO: worker thread finished; awaiting finish of 4 more threads
# INFO: worker thread finished; awaiting finish of 3 more threads
# INFO: worker thread finished; awaiting finish of 2 more threads

# %%
# Run
import configparser
config = configparser.ConfigParser()
config.read("dfl2022.cfg")
output_folder=config['DOCUMENT']['cache_dir']

# %%
#Gensim format
#Run
gensim_model.save(output_folder+"ontology"+'_'+config['DOCUMENT']['walk_depth']+".embeddings")

# %%
#Txt format
#Run
gensim_model.wv.save_word2vec_format(output_folder+"ontology"+'_'+config['DOCUMENT']['walk_depth']+".embeddings.txt", binary=False)

# %% [markdown]
# ## Loading embeddings and getting similarities

# %%
from gensim.models import KeyedVectors

#Embedding vectors generated above
model = KeyedVectors.load(output_folder+"ontology"+'_'+config['DOCUMENT']['walk_depth']+".embeddings", mmap='r')
wv = model.wv

vector = wv['committee']  # Get numpy vector of a word
print("Vector for 'committee'")
print(vector)
print()

#cosine similarity
similarity = wv.similarity('committee', 'http://conference#Committee')
print("Similarity between committee and http://conference#Committee", similarity)
print()

similarity = wv.similarity('http://conference#Reviewer', 'reviewer')
print(similarity)
print()

#Most similar cosine similarity
result = wv.most_similar(positive=['reviewer', 'committee'])
print(result)
print()

#Most similar entities: cosmul
result = wv.most_similar_cosmul(positive=['reviewer'])
print(result)
print()
# Out:
# INFO: loading Word2VecKeyedVectors object from ./caches_omim2ordo/ontology_3.embeddings
# INFO: loading wv recursively from ./caches_omim2ordo/ontology_3.embeddings.wv.* with mmap=r
# INFO: setting ignored attribute vectors_norm to None
# INFO: loading vocabulary recursively from ./caches_omim2ordo/ontology_3.embeddings.vocabulary.* with mmap=r
# INFO: loading trainables recursively from ./caches_omim2ordo/ontology_3.embeddings.trainables.* with mmap=r
# INFO: setting ignored attribute cum_table to None
# INFO: loaded ./caches_omim2ordo/ontology_3.embeddings
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 7
#       4 model = KeyedVectors.load(output_folder+"ontology"+'_'+config['DOCUMENT']['walk_depth']+".embeddings", mmap='r')
#       5 wv = model.wv
# ----> 7 vector = wv['committee']  # Get numpy vector of a word
#       8 print("Vector for 'committee'")
#       9 print(vector)
#
# File c:\users\sev_s\appdata\local\programs\python\python38\lib\site-packages\gensim\models\keyedvectors.py:353, in BaseKeyedVectors.__getitem__(self, entities)
#     338 """Get vector representation of `entities`.
#     339
#     340 Parameters
#    (...)
#     349
#     350 """
#     351 if isinstance(entities, string_types):
#     352     # allow calls like trained_model['office'], as a shorthand for trained_model[['office']]
# --> 353     return self.get_vector(entities)
#     355 return vstack([self.get_vector(entity) for entity in entities])
#
# File c:\users\sev_s\appdata\local\programs\python\python38\lib\site-packages\gensim\models\keyedvectors.py:471, in WordEmbeddingsKeyedVectors.get_vector(self, word)
#     470 def get_vector(self, word):
# --> 471     return self.word_vec(word)
#
# File c:\users\sev_s\appdata\local\programs\python\python38\lib\site-packages\gensim\models\keyedvectors.py:468, in WordEmbeddingsKeyedVectors.word_vec(self, word, use_norm)
#     466     return result
#     467 else:
# --> 468     raise KeyError("word '%s' not in vocabulary" % word)
#
# KeyError: "word 'committee' not in vocabulary"

# %%
# Run
from gensim.models import Word2Vec
model = Word2Vec.load(output_folder+"ontology"+'_'+config['DOCUMENT']['walk_depth']+".embeddings")

# %%
# Run
ranking_results = []
# save the scored candidate mappings in the same format as the original test.cands.tsv
f = open("scored.test.cands.tsv", "w")
f.write("SrcEntity" +'\t'+ "TgtEntity" +'\t'+ "TgtCandidates\n")
file = open(r"C:\Users\sev_s\Documents\OWL2Vec-Star\case_studies\alignment\Data\omim2ordo2022.test.cands.tsv")

for i in file.readlines()[1:]:
    src_ref_class = i.split('\t')[0]
    tgt_ref_class = i.split('\t')[1]
    tgt_cands = i.split('\t')[2]
    # print(src_ref_class, tgt_ref_class, tgt_cands)
    tgt_cands = eval(tgt_cands)  # transform string into list or sequence
    scored_cands = []
    for tgt_cand in tgt_cands:
        # assign a score to each candidate with an OM system
        try:
            matching_score = model.wv.similarity(src_ref_class, tgt_cand)
        except:
            matching_score = 0
        scored_cands.append([tgt_cand, matching_score])
    ranking_results.append([src_ref_class, tgt_ref_class, scored_cands])
    f.write(f'{src_ref_class}\t{tgt_ref_class}\t{scored_cands}\n')
print("done")

# %%
# Run
import numpy as np
distance_results = []
# save the scored candidate mappings in the same format as the original test.cands.tsv
f = open("distance.test.cands.tsv", "w")
f.write("SrcEntity" +'\t'+ "TgtEntity" +'\t'+ "TgtCandidates\n")
file = open(r"C:\Users\sev_s\Documents\OWL2Vec-Star\case_studies\alignment\Data\omim2ordo2022.test.cands.tsv")

for i in file.readlines()[1:]:
    src_ref_class = i.split('\t')[0]
    tgt_ref_class = i.split('\t')[1]
    tgt_cands = i.split('\t')[2]
    # print(src_ref_class, tgt_ref_class, tgt_cands)
    tgt_cands = eval(tgt_cands)  # transform string into list or sequence
    scored_cands = []
    for tgt_cand in tgt_cands:
        # assign a score to each candidate with an OM system
        try:
            euc_dist = np.linalg.norm(model.wv[src_ref_class] - model.wv[tgt_cand])
        except:
            euc_dist = np.inf
        scored_cands.append([tgt_cand, euc_dist])
    distance_results.append([src_ref_class, tgt_ref_class, scored_cands])
    f.write(f'{src_ref_class}\t{tgt_ref_class}\t{scored_cands}\n')
print("done")

# %%
# Run
from gensim.models import Word2Vec
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import numpy as np
import matplotlib.pyplot as plt

# Load your Word2Vec model
model = Word2Vec.load(output_folder+"ontology"+'_'+config['DOCUMENT']['walk_depth']+".embeddings")

# Extract word vectors and corresponding words
words = list(model.wv.vocab.keys())
vectors = [model.wv[word] for word in words]

# Apply PCA to reduce dimensionality
num_dimensions = 2
pca = PCA(n_components=num_dimensions)
vectors_pca = pca.fit_transform(vectors)

# Elbow method for finding number of clusters

wcss = [] 
for i in range(1, 16): 
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(vectors_pca) 
    wcss.append(kmeans.inertia_)

plt.plot(range(1,16), wcss)

# %%
# Apply KMeans clustering
num_clusters = 5  # You can change this based on your preference
kmeans = KMeans(n_clusters=num_clusters)
kmeans.fit(vectors_pca)

# Visualize the clusters
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']
for i in range(num_clusters):
    cluster_points = np.array([vectors_pca[j] for j in range(len(words)) if kmeans.labels_[j] == i])
    plt.scatter(cluster_points[:, 0], cluster_points[:, 1], c=colors[i], label=f'Cluster {i + 1}')

plt.title('Train-Val+ AML union LOgmap')
plt.legend()
plt.show()

# %%
import random

# Choose a random index within the range of the words list
random_index = random.sample(range(len(words)), 30)

vector = {
    'X':vectors_pca[:,0],
    'Y':vectors_pca[:,1],
    'words': np.array(words),
    'label':kmeans.labels_
}

sample_vectors_pca = np.array([vector['X'][random_index], vector['Y'][random_index]]).T
sample_words = np.array(vector['words'][random_index])
sample_cluster = np.array(vector['label'][random_index])

# Visualize the clusters
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']
markers = ['o', 'v', '^', '<', '>', 's', 'p', 'h', 'x', '+', 'd', '|', '_']

for i in range(num_clusters):
    cluster_points = np.array([sample_vectors_pca[j] for j in range(len(sample_words)) if sample_cluster[j] == i])
    plt.scatter(cluster_points[:,0], cluster_points[:,1], c=colors[i], marker=markers[i])

for i, txt in enumerate(sample_words):
    plt.annotate(txt, (sample_vectors_pca[i,0], sample_vectors_pca[i,1]), fontsize=5)
